# %%
import pandas as pd
from ggplot import *
# %matplotlib inline

# %%
df = pd.read_csv("data/week2-HW-data.csv")

# %%
df.head(5)
# Out:
#    Person  SBP   QUET  AGE  SMK
# 0       1  135  2.876   45    0
# 1       2  122  3.251   41    0
# 2       3  130  3.100   49    0
# 3       4  148  3.768   52    0
# 4       5  146  2.979   54    1

# %% [markdown]
# Question 1
#
# * SBP (Y) vs. QUET (X)
# * SBP (Y) vs. SMK (X)
# * QUET (Y) vs. AGE (X)
# * SBP (Y) vs. AGE (X)

# %%
ggplot(df, aes('QUET','SBP')) + \
     geom_point(colour="black", size = 100) +\
    geom_point(colour="pink", size = 40) + \
    ggtitle("SBP (Y) vs. QUET (X)")
# Out:
# <ggplot: (278681829)>

# %%
ggplot(df, aes('SMK','SBP')) + \
     geom_point(colour="black", size = 100) +\
    geom_point(colour="pink", size = 40) + \
    ggtitle("SBP (Y) vs. SMK (X)")
# Out:
# <ggplot: (284216809)>

# %%
ggplot(df, aes('AGE','QUET')) + \
     geom_point(colour="black", size = 100) +\
    geom_point(colour="pink", size = 40) + \
    ggtitle("QUET (Y) vs. AGE (X)")
# Out:
# <ggplot: (278682629)>

# %%
ggplot(df, aes('AGE','SBP')) + \
     geom_point(colour="black", size = 100) +\
    geom_point(colour="pink", size = 40) + \
    ggtitle("SBP (Y) vs. AGE (X)")
# Out:
# <ggplot: (282616681)>

# %% [markdown]
# I am not doing Question 2 because it is really dumb, and I might actually lose brain cells trying to do it

# %%
from sklearn.linear_model import LinearRegression
import numpy as np
import scipy as sp
import statsmodels.api as sm

# %%
X = df[["AGE"]].values
X = sm.add_constant(X)  # add the intercept term
y = df["SBP"].values
ols = sm.OLS(y, X).fit()
ols.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.601
# Model:                            OLS   Adj. R-squared:                  0.588
# Method:                 Least Squares   F-statistic:                     45.18
# Date:                Tue, 07 Apr 2015   Prob (F-statistic):           1.89e-07
# Time:                        23:33:52   Log-Likelihood:                -115.55
# No. Observations:                  32   AIC:                             235.1
# Df Residuals:                      30   BIC:                             238.0
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# const         59.0916     12.816      4.611      0.000        32.917    85.266
# x1             1.6045      0.239      6.721      0.000         1.117     2.092
# ==============================================================================
# Omnibus:                        4.016   Durbin-Watson:                   1.098
# Prob(Omnibus):                  0.134   Jarque-Bera (JB):                3.122
# Skew:                           0.764   Prob(JB):                        0.210
# Kurtosis:                       3.064   Cond. No.                         421.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
ax = df.plot(x="AGE", y="SBP", style="o")
#ax.set_ylabel("medv")

stats = df["SBP"].values
xs = range(int(np.min(X[:,0])), int(np.max(X[:,0])))
ys = [reg.predict([x]) for x in xs]
ax.plot(xs, ys, 'r', linewidth=2.5)
